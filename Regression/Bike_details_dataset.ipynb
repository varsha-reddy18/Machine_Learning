# %% [markdown]
# # Bike Details Dataset

# %% [markdown]
# ### Load DataSet

# %%
import pandas as pd
df=pd.read_csv("C:/Bike_Rental_data.csv")
df
# Out:
# C:\Users\Varsha\AppData\Local\Temp\ipykernel_16480\1366819518.py:2: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("C:/Bike_Rental_data.csv")
#              instant      dteday    season    yr mnth         hr holiday  \
# 0           0.992410    1/1/2011  springer  2011    1  -0.009452      No
# 1           2.004157    1/1/2011  springer  2011    1   1.007925      No
# 2           2.984610    1/1/2011  springer  2011    1   1.993083      No
# 3           3.993251    1/1/2011  springer  2011    1   2.991451      No
# 4           4.990763    1/1/2011  springer  2011    1   4.024688      No
# ...              ...         ...       ...   ...  ...        ...     ...
# 100571  15381.008637   8/10/2012    winter  2012   10   0.994542     Yes
# 100572   6862.005774  18-10-2011    winter  2011   10  11.004787      No
# 100573   6094.996743  16-09-2011      fall  2011    9  12.016090      No
# 100574   6345.999240  26-09-2011    winter  2011    9  22.991130      No
# 100575  13961.018918    9/8/2012      fall  2012    8  20.994953      No
#
#          weekday   workingday weathersit  temp   atemp   hum windspeed casual  \
# 0       5.990616      No work      Clear  0.24  0.2879  0.81         0      3
# 1       5.996162      No work      Clear  0.22  0.2727   0.8         0      8
# 2       6.004768      No work      Clear  0.22  0.2727     ?         0      5
# 3       5.980473      No work      Clear  0.24  0.2879  0.75         0      3
# 4       5.984412      No work      Clear  0.24  0.2879  0.75         0      0
# ...          ...          ...        ...   ...     ...   ...       ...    ...
# 100571  1.002294      No work      Clear  0.34  0.3333  0.87    0.1642      2
# 100572  2.007197  Working Day       Mist   0.6  0.6212  0.49    0.1045     35
# 100573  5.000102  Working Day       Mist  0.52     0.5  0.45         0     39
# 100574  0.988453  Working Day      Clear  0.62  0.5455  0.94    0.1343     11
# 100575  4.017469  Working Day       Mist   0.7  0.6515  0.58    0.1642     50
#
#        registered         cnt
# 0              13   15.999019
# 1              32   40.004970
# 2              27   32.004786
# 3              10   12.999856
# 4               1    1.002089
# ...           ...         ...
# 100571         35   36.990489
# 100572        112  147.007249
# 100573        212  250.998909
# 100574         64   75.003145
# 100575        286  336.015431
#
# [100576 rows x 17 columns]

# %%
df.shape
# Out:
# (100576, 17)

# %%
df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100576 entries, 0 to 100575
# Data columns (total 17 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   instant     100576 non-null  float64
#  1   dteday      100576 non-null  object
#  2   season      100576 non-null  object
#  3   yr          100576 non-null  object
#  4   mnth        100576 non-null  object
#  5   hr          100576 non-null  float64
#  6   holiday     100576 non-null  object
#  7   weekday     100576 non-null  float64
#  8   workingday  100576 non-null  object
#  9   weathersit  100576 non-null  object
#  10  temp        100576 non-null  object
#  11  atemp       100576 non-null  object
#  12  hum         100576 non-null  object
#  13  windspeed   100576 non-null  object
#  14  casual      100576 non-null  object
#  15  registered  100576 non-null  object
#  16  cnt         100576 non-null  float64
# dtypes: float64(4), object(13)
# memory usage: 13.0+ MB

# %%
df.describe()
# Out:
#              instant             hr        weekday            cnt
# count  100576.000000  100576.000000  100576.000000  100576.000000
# mean     8688.878771      11.552431       3.002402     189.332859
# std      5019.386012       6.921326       2.008345     181.247215
# min         0.987460      -0.037539      -0.040162       0.976830
# 25%      4345.006095       5.986351       1.006304      39.998170
# 50%      8686.993279      11.986028       3.000195     141.998595
# 75%     13038.998689      17.983380       4.993783     280.989003
# max     17379.006826      23.037515       6.039560     977.012922

# %%
df.head()
# Out:
#     instant    dteday    season    yr mnth        hr holiday   weekday  \
# 0  0.992410  1/1/2011  springer  2011    1 -0.009452      No  5.990616
# 1  2.004157  1/1/2011  springer  2011    1  1.007925      No  5.996162
# 2  2.984610  1/1/2011  springer  2011    1  1.993083      No  6.004768
# 3  3.993251  1/1/2011  springer  2011    1  2.991451      No  5.980473
# 4  4.990763  1/1/2011  springer  2011    1  4.024688      No  5.984412
#
#   workingday weathersit  temp   atemp   hum windspeed casual registered  \
# 0    No work      Clear  0.24  0.2879  0.81         0      3         13
# 1    No work      Clear  0.22  0.2727   0.8         0      8         32
# 2    No work      Clear  0.22  0.2727     ?         0      5         27
# 3    No work      Clear  0.24  0.2879  0.75         0      3         10
# 4    No work      Clear  0.24  0.2879  0.75         0      0          1
#
#          cnt
# 0  15.999019
# 1  40.004970
# 2  32.004786
# 3  12.999856
# 4   1.002089

# %% [markdown]
# ### Handling missing values

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
num_cols = df.select_dtypes(include=["int64","float64"]).columns
cat_cols = df.select_dtypes(include=["object"]).columns

# %% [markdown]
# ### Error / Outlier Handling

# %%
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) |
          (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ### Distribution Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in num_cols:
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
for col in cat_cols:
    sns.countplot(x=df[col])
    plt.title(f"Count Plot of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Correlation Matrix & Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Hypothesis Testing

# %%
df[["temp", "cnt"]].dtypes
# Out:
# temp     object
# cnt     float64
# dtype: object

# %%
df["temp"] = pd.to_numeric(df["temp"], errors="coerce")
df["cnt"]  = pd.to_numeric(df["cnt"], errors="coerce")
# Out:
# C:\Users\Varsha\AppData\Local\Temp\ipykernel_16480\2937899561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["temp"] = pd.to_numeric(df["temp"], errors="coerce")
# C:\Users\Varsha\AppData\Local\Temp\ipykernel_16480\2937899561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["cnt"]  = pd.to_numeric(df["cnt"], errors="coerce")

# %%
df = df.dropna(subset=["temp", "cnt"])

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(df["temp"], df["cnt"])
corr, p_value
# Out:
# (np.float64(0.4026567245092972), np.float64(0.0))

# %% [markdown]
# ### Encoding (Categorical → Numerical) One-Hot Encoding

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

X = df_encoded.drop("cnt", axis=1)
y = df_encoded["cnt"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

# %%
import numpy as np
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2, mse, rmse, mae
# Out:
# (0.999999995603572,
#  0.00010572723284466839,
#  np.float64(0.010282374864041302),
#  0.008190138107894351)

# %% [markdown]
# ### Polynomial Regression

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# Example numeric features in bike_rental dataset
num_features = ["temp", "atemp", "hum", "windspeed"]

# Select numeric features
X_num = df[num_features].copy()
y = df["cnt"].copy()

# %%
# Convert any invalid strings to numeric (coerce errors to NaN)
for col in X_num.columns:
    X_num[col] = pd.to_numeric(X_num[col], errors="coerce")

# Drop rows with NaN in X_num or y
X_num = X_num.dropna()
y_clean = y.loc[X_num.index]  # Keep target aligned

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_num)

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X_scaled)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, y_clean, test_size=0.2, random_state=42
)

# %%
lr_poly = LinearRegression()
lr_poly.fit(X_train, y_train)

y_pred = lr_poly.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)

print(f"R2 Score: {r2:.4f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
# Out:
# R2 Score: 0.2956
# MSE: 16700.08
# RMSE: 129.23
# MAE: 100.40

# %% [markdown]
# ### Lasso & Ridge Regression (Best Alpha)

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import GridSearchCV

alphas = {"alpha":[0.001,0.01,0.1,1,10,100]}

ridge = GridSearchCV(Ridge(), alphas, cv=5)
ridge.fit(X_train, y_train)

lasso = GridSearchCV(Lasso(max_iter=5000), alphas, cv=5)
lasso.fit(X_train, y_train)

ridge.best_params_, lasso.best_params_
# Out:
# ({'alpha': 10}, {'alpha': 0.001})

# %%
best_lasso = lasso.best_estimator_
y_pred_lasso = best_lasso.predict(X_test)

r2_score(y_test, y_pred_lasso),
mean_squared_error(y_test, y_pred_lasso),
np.sqrt(mean_squared_error(y_test, y_pred_lasso)),
mean_absolute_error(y_test, y_pred_lasso)
# Out:
# 100.3955244657056
